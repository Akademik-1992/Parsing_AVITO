# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests, lxml, webbrowser, re, random, datetime
import time, openpyxl, json, warnings, time
from tqdm import tqdm
import datetime
from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# %%time

current_date = date.today()
print(f'Дата загрузки {current_date}')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('Драйвер загружен!')

df_old_import_cars = pd.DataFrame(columns=['Date_download', 'Model', 'Year', 'Price', 'Odometer', 'Location', 'Date_publication', 'Link'])

for page in range(1, 101):

    df_help = pd.DataFrame()
    
    url = f'https://www.avito.ru/stavropolskiy_kray/avtomobili/s_probegom-ASgBAgICAUSGFMjmAQ?f=ASgBAQICAUSGFMjmAQFAhNEShIDJ2hGoydoRksnaEZzJ2hGiydoR_MjaEabJ2hGIydoR&p={page}&s=104'
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')

    models = soup.find_all('h3', class_='styles-module-root-s3nJ7 styles-module-root-s4tZ2 styles-module-size_l-j3Csw styles-module-size_l_compensated-trWgn styles-module-size_l-ai2ZG styles-module-ellipsis-A5gkK styles-module-weight_bold-Bh2pN stylesMarningNormal-module-root-_xKyG stylesMarningNormal-module-header-l-GrtnL')
    model_lst = [car.next.split(', ')[0] for car in models]
    year_lst = [car.next.split(', ')[1] for car in models]
    odometer_lst = [car.next.split(', ')[2] for car in models]
    odometer_lst = [''.join(num for num in price if num.isdigit()) for price in odometer_lst] # Удаление всего, кроме цифр
    date_download = [current_date] * len(model_lst)

    prices = soup.find_all('strong')
    price_lst = [price.find('span', class_='').next for price in prices if price.find('span', class_='') is not None]
    price_lst = [''.join(num for num in price if num.isdigit()) for price in price_lst]

    links = soup.find_all('div', class_='iva-item-title-CdRXl')
    links_lst = [f'www.avito.ru{link.find("a", class_="styles-module-root-m3BML styles-module-root_noVisited-HHF0s").get("href")}' for link in links]

    dates = soup.find_all('div', class_='iva-item-dateInfoStep-qcDJA')
    date_publication_lst = [date.find('p', class_='styles-module-root-s4tZ2 styles-module-size_s-nEvE8 styles-module-size_s-PDQal stylesMarningNormal-module-root-_xKyG stylesMarningNormal-module-paragraph-s-HX94M styles-module-noAccent-XIvJm').text for date in dates]

    locations = soup.find_all('div', class_='geo-root-NrkbV')
    locations_lst = [location.find('span').text for location in locations]    

    df_help['Date_download'] = date_download
    df_help['Model'] = model_lst
    df_help['Year'] = year_lst
    df_help['Price'] = price_lst
    df_help['Odometer'] = odometer_lst
#   df_help['Seller'] = seller_lst
    df_help['Location'] = locations_lst
    df_help['Date_publication'] = date_publication_lst
    df_help['Link'] = links_lst   
    
    df_old_import_cars = pd.concat([df_old_import_cars, df_help], ignore_index=True)
    
    print(f'Обработана страница {page}. Всего загружено {len(df_old_import_cars)} машин.')
    
    df_old_import_cars.to_excel(f'Автомобили/Импортные_авто_с_пробегом_{current_date}.xlsx', index=False)

df_old_import_cars_Final = df_old_import_cars.drop_duplicates()
df_old_import_cars_Final.to_excel(f'Автомобили/Импортные_авто_с_пробегом_{current_date}.xlsx', index=False)
# Out:
# Дата загрузки 2024-11-11
# Драйвер загружен!
# Обработана страница 1. Всего загружено 50 машин.
# Обработана страница 2. Всего загружено 100 машин.
# Обработана страница 3. Всего загружено 150 машин.
# Обработана страница 4. Всего загружено 200 машин.
# Обработана страница 5. Всего загружено 250 машин.
# Обработана страница 6. Всего загружено 300 машин.
# Обработана страница 7. Всего загружено 350 машин.
# Обработана страница 8. Всего загружено 400 машин.
# Обработана страница 9. Всего загружено 450 машин.
# Обработана страница 10. Всего загружено 500 машин.
# Обработана страница 11. Всего загружено 550 машин.
# Обработана страница 12. Всего загружено 600 машин.
# Обработана страница 13. Всего загружено 650 машин.
# Обработана страница 14. Всего загружено 700 машин.
# Обработана страница 15. Всего загружено 750 машин.
# Обработана страница 16. Всего загружено 800 машин.
# Обработана страница 17. Всего загружено 850 машин.
# Обработана страница 18. Всего загружено 900 машин.
# Обработана страница 19. Всего загружено 950 машин.
# Обработана страница 20. Всего загружено 1000 машин.
# Обработана страница 21. Всего загружено 1050 машин.
# Обработана страница 22. Всего загружено 1100 машин.
# Обработана страница 23. Всего загружено 1150 машин.
# Обработана страница 24. Всего загружено 1200 машин.
# Обработана страница 25. Всего загружено 1250 машин.
# Обработана страница 26. Всего загружено 1300 машин.
# Обработана страница 27. Всего загружено 1350 машин.
# Обработана страница 28. Всего загружено 1400 машин.
# Обработана страница 29. Всего загружено 1450 машин.
# Обработана страница 30. Всего загружено 1500 машин.
# Обработана страница 31. Всего загружено 1550 машин.
# Обработана страница 32. Всего загружено 1600 машин.
# Обработана страница 33. Всего загружено 1650 машин.
# Обработана страница 34. Всего загружено 1700 машин.
# Обработана страница 35. Всего загружено 1750 машин.
# Обработана страница 36. Всего загружено 1800 машин.
# Обработана страница 37. Всего загружено 1849 машин.
# Обработана страница 38. Всего загружено 1899 машин.
# Обработана страница 39. Всего загружено 1949 машин.
# Обработана страница 40. Всего загружено 1999 машин.
# Обработана страница 41. Всего загружено 2049 машин.
# Обработана страница 42. Всего загружено 2099 машин.
# Обработана страница 43. Всего загружено 2149 машин.
# Обработана страница 44. Всего загружено 2199 машин.
# Обработана страница 45. Всего загружено 2249 машин.
# Обработана страница 46. Всего загружено 2299 машин.
# Обработана страница 47. Всего загружено 2349 машин.
# Обработана страница 48. Всего загружено 2399 машин.
# Обработана страница 49. Всего загружено 2449 машин.
# Обработана страница 50. Всего загружено 2499 машин.
# Обработана страница 51. Всего загружено 2549 машин.
# Обработана страница 52. Всего загружено 2599 машин.
# Обработана страница 53. Всего загружено 2649 машин.
# Обработана страница 54. Всего загружено 2699 машин.
# Обработана страница 55. Всего загружено 2749 машин.
# Обработана страница 56. Всего загружено 2799 машин.
# Обработана страница 57. Всего загружено 2849 машин.
# Обработана страница 58. Всего загружено 2899 машин.
# Обработана страница 59. Всего загружено 2949 машин.
# Обработана страница 60. Всего загружено 2999 машин.
# Обработана страница 61. Всего загружено 3049 машин.
# Обработана страница 62. Всего загружено 3099 машин.
# Обработана страница 63. Всего загружено 3149 машин.
# Обработана страница 64. Всего загружено 3199 машин.
# Обработана страница 65. Всего загружено 3249 машин.
# Обработана страница 66. Всего загружено 3299 машин.
# Обработана страница 67. Всего загружено 3349 машин.
# Обработана страница 68. Всего загружено 3399 машин.
# Обработана страница 69. Всего загружено 3449 машин.
# Обработана страница 70. Всего загружено 3499 машин.
# Обработана страница 71. Всего загружено 3549 машин.
# Обработана страница 72. Всего загружено 3599 машин.
# Обработана страница 73. Всего загружено 3649 машин.
# Обработана страница 74. Всего загружено 3699 машин.
# Обработана страница 75. Всего загружено 3749 машин.
# Обработана страница 76. Всего загружено 3799 машин.
# Обработана страница 77. Всего загружено 3849 машин.
# Обработана страница 78. Всего загружено 3899 машин.
# Обработана страница 79. Всего загружено 3949 машин.
# Обработана страница 80. Всего загружено 3999 машин.
# Обработана страница 81. Всего загружено 4049 машин.
# Обработана страница 82. Всего загружено 4099 машин.
# Обработана страница 83. Всего загружено 4149 машин.
# Обработана страница 84. Всего загружено 4199 машин.
# Обработана страница 85. Всего загружено 4249 машин.
# Обработана страница 86. Всего загружено 4299 машин.
# Обработана страница 87. Всего загружено 4349 машин.
# Обработана страница 88. Всего загружено 4399 машин.
# Обработана страница 89. Всего загружено 4449 машин.
# Обработана страница 90. Всего загружено 4499 машин.
# Обработана страница 91. Всего загружено 4549 машин.
# Обработана страница 92. Всего загружено 4599 машин.
# Обработана страница 93. Всего загружено 4649 машин.
# Обработана страница 94. Всего загружено 4699 машин.
# Обработана страница 95. Всего загружено 4749 машин.
# Обработана страница 96. Всего загружено 4799 машин.
# Обработана страница 97. Всего загружено 4849 машин.
# Обработана страница 98. Всего загружено 4899 машин.
# Обработана страница 99. Всего загружено 4949 машин.
# Обработана страница 100. Всего загружено 4999 машин.
# CPU times: total: 1min 12s
# Wall time: 34min 56s

# %% [markdown]
# # Отладка кода

# %%
current_date = date.today()
print(f'Дата загрузки {current_date}')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
print('Драйвер успешно загружен!')

url = f'https://www.avito.ru/stavropolskiy_kray/avtomobili/s_probegom-ASgBAgICAUSGFMjmAQ?f=ASgBAQICAUSGFMjmAQFAhNEShIDJ2hGoydoRksnaEZzJ2hGiydoR_MjaEabJ2hGIydoR&p=1&s=104'
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
df_help = pd.DataFrame()
    
models = soup.find_all('h3', class_='styles-module-root-s3nJ7 styles-module-root-s4tZ2 styles-module-size_l-j3Csw styles-module-size_l_compensated-trWgn styles-module-size_l-ai2ZG styles-module-ellipsis-A5gkK styles-module-weight_bold-Bh2pN stylesMarningNormal-module-root-_xKyG stylesMarningNormal-module-header-l-GrtnL')
model_lst = [car.next.split(', ')[0] for car in models]
year_lst = [car.next.split(', ')[1] for car in models]
odometer_lst = [car.next.split(', ')[2] for car in models]
odometer_lst = [''.join(num for num in price if num.isdigit()) for price in odometer_lst] # Удаление всего, кроме цифр
date_download = [current_date] * len(model_lst)

prices = soup.find_all('strong')
price_lst = [price.find('span', class_='').next for price in prices if price.find('span', class_='') is not None]
price_lst = [''.join(num for num in price if num.isdigit()) for price in price_lst]

links = soup.find_all('div', class_='iva-item-title-CdRXl')
links_lst = [f'www.avito.ru{link.find("a", class_="styles-module-root-m3BML styles-module-root_noVisited-HHF0s").get("href")}' for link in links]

dates = soup.find_all('div', class_='iva-item-dateInfoStep-qcDJA')
date_publication_lst = [date.find('p', class_='styles-module-root-s4tZ2 styles-module-size_s-nEvE8 styles-module-size_s-PDQal stylesMarningNormal-module-root-_xKyG stylesMarningNormal-module-paragraph-s-HX94M styles-module-noAccent-XIvJm').text for date in dates]

locations = soup.find_all('div', class_='geo-root-NrkbV')
locations_lst = [location.find('span').text for location in locations]    

df_help['Date_download'] = date_download
df_help['Model'] = model_lst
df_help['Year'] = year_lst
df_help['Price'] = price_lst
df_help['Odometer'] = odometer_lst
# df_help['Seller'] = seller_lst
df_help['Location'] = locations_lst
df_help['Date_publication'] = date_publication_lst
df_help['Link'] = links_lst

# %%
df_help

# %%
models = soup.find_all('h3', class_='styles-module-root-s3nJ7 styles-module-root-s4tZ2 styles-module-size_l-j3Csw styles-module-size_l_compensated-trWgn styles-module-size_l-ai2ZG styles-module-ellipsis-A5gkK styles-module-weight_bold-Bh2pN stylesMarningNormal-module-root-_xKyG stylesMarningNormal-module-header-l-GrtnL')

# %%
model_lst = [car.next.split(', ')[0] for car in models]
year_lst = [car.next.split(', ')[1] for car in models]
odometer_lst = [car.next.split(', ')[2] for car in models]
odometer_lst = [''.join(num for num in price if num.isdigit()) for price in odometer_lst] # Удаление всего, кроме цифр

# %%
odometer_lst
